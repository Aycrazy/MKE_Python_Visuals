# %%
import requests as req
from bs4 import BeautifulSoup
import json
import pandas as pd
from standardize import *
from key import api_key
from key import g_api_key
import re
import os
import math
import bokeh as bo
import numpy as np 
from helper import *
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn
import os
import re
from bokeh.io import export_png
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from bokeh.palettes import Category20
from bokeh.palettes import Spectral6
from bokeh.transform import factor_cmap
from bokeh.models import ColumnDataSource, HoverTool, Cross
from math import pi

# %%
civ_comps = 'https://data.milwaukee.gov/api/3/action/datastore_search?resource_id=cd1ca96a-88dc-4af5-b813-e01bc9e1121f'
cc_df = pull_data(civ_comps,'',api_key)

# %%
cc_df.shape
# Out:
# (226, 9)

# %%
cc_df.head()
# Out:
#                Category1 Category2 Category3 DateClosed DateReported  \
# 0          No Allegation      None      None  1/23/2018     1/2/2018
# 1          No Allegation      None      None   1/8/2018     1/5/2018
# 2          No Allegation      None      None   1/9/2018     1/8/2018
# 3  Department Procedures      None      None  2/21/2018    1/10/2018
# 4  Department Procedures      None      None  1/16/2018    1/16/2018
#
#                     Department IdentificationNumber  Status  _id
# 0  Milwaukee Police Department            2018-0001  Closed    1
# 1  Milwaukee Police Department            2018-0002  Closed    2
# 2  Milwaukee Police Department            2018-0003  Closed    3
# 3  Milwaukee Police Department            2018-0004  Closed    4
# 4  Milwaukee Police Department            2018-0005  Closed    5

# %%
cc_df.Department.value_counts()
# Out:
# Milwaukee Police Department                               186
# NON EMPLOYEE                                               23
# Milwaukee Fire Department                                  15
# Voided Incident                                             1
# Milwaukee Fire Department, Milwaukee Police Department      1
# Name: Department, dtype: int64

# %%
cc_df.Category1.value_counts()
# Out:
# Department Procedures                84
# Department Services                  74
# No Allegation                        32
# Discourtesy                          22
# Use of Force                          6
# Unjustified Search                    3
# Other                                 2
# #NAME?                                1
# Voided Incident                       1
# Race/Ethnicity based traffic stop     1
# Name: Category1, dtype: int64

# %%
cc_df.rename(columns={'Category1':'Case_type'}, inplace=True)

# %%
civ_comps_dict = 'cd1ca96a-88dc-4af5-b813-e01bc9e1121f-data-dictionary.csv'
ccd_df = pd.read_csv(civ_comps_dict)

# %%
ccd_df
# Out:
#                  column  type                   label  \
# 0  IdentificationNumber  text  Identification Number
# 1            Department  text             Department
# 2                Status  text                  Status
# 3          DateReported  text           Date Reported
# 4            DateClosed  text             Date Closed
# 5             Category1  text             Category 1
# 6             Category2  text             Category 2
# 7             Category3  text             Category 3
#
#                                          description
# 0  Generic identification number for each complai...
# 1  The department which the complaint is in regar...
# 2  If the investigation is complete the status is...
# 3  The date that the complaint was received by th...
# 4  The date the investigation completed, when app...
# 5  A general description of the nature of the com...
# 6  Complaints with multiple allegations regarding...
# 7  Complaints with multiple allegations regarding...

# %%
add_year_month_day_df(cc_df,'DateReported','Reported')

# %%
closed_cases_df = cc_df[cc_df.Status=='Closed']

# %%
add_year_month_day_df(closed_cases_df,'DateClosed','Closed')
# Out:
# /Users/ayaspan/Documents/Personal/MKE_Python_Visuals/standardize.py:374: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[date_pre+'_dtime'] = df[date_col].apply(get_datetime)
# /Users/ayaspan/Documents/Personal/MKE_Python_Visuals/standardize.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[date_pre+'Year'] = df[date_pre+'_dtime'].apply(get_year)
# /Users/ayaspan/Documents/Personal/MKE_Python_Visuals/standardize.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[date_pre+'Month'] = df[date_pre+'_dtime'].apply(get_month)
# /Users/ayaspan/Documents/Personal/MKE_Python_Visuals/standardize.py:377: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[date_pre+'Day'] = df[date_pre+'_dtime'].apply(get_day)

# %%
closed_cases_df.shape
# Out:
# (219, 17)

# %%
closed_cases_df.head()
# Out:
#                Case_type Category2 Category3 DateClosed DateReported  \
# 0          No Allegation      None      None  1/23/2018     1/2/2018
# 1          No Allegation      None      None   1/8/2018     1/5/2018
# 2          No Allegation      None      None   1/9/2018     1/8/2018
# 3  Department Procedures      None      None  2/21/2018    1/10/2018
# 4  Department Procedures      None      None  1/16/2018    1/16/2018
#
#                     Department IdentificationNumber  Status  _id  \
# 0  Milwaukee Police Department            2018-0001  Closed    1
# 1  Milwaukee Police Department            2018-0002  Closed    2
# 2  Milwaukee Police Department            2018-0003  Closed    3
# 3  Milwaukee Police Department            2018-0004  Closed    4
# 4  Milwaukee Police Department            2018-0005  Closed    5
#
#   Reported_dtime  ReportedYear  ReportedMonth  ReportedDay Closed_dtime  \
# 0     2018-01-02          2018              1            1   2018-01-23
# 1     2018-01-05          2018              1            4   2018-01-08
# 2     2018-01-08          2018              1            0   2018-01-09
# 3     2018-01-10          2018              1            2   2018-02-21
# 4     2018-01-16          2018              1            1   2018-01-16
#
#    ClosedYear  ClosedMonth  ClosedDay
# 0        2018            1          1
# 1        2018            1          0
# 2        2018            1          1
# 3        2018            2          2
# 4        2018            1          1

# %%
closed_cases_df['Date_to_Close'] = closed_cases_df.Closed_dtime-closed_cases_df.Reported_dtime
# Out:
# /Users/ayaspan/anaconda3/envs/mke_calls/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
real_cats = list(closed_cases_df.Case_type.value_counts().to_frame()[:8].reset_index()['index'])
real_cats = [cat for cat in real_cats if cat !='#NAME?']

# %%
print(real_cats)
# Out:
# ['Department Procedures', 'Department Services', 'No Allegation', 'Discourtesy', 'Use of Force', 'Unjustified Search', 'Other']

# %%
clean_closed_df = closed_cases_df[closed_cases_df.Case_type.isin(real_cats)]

# %%
clean_closed_df['Days_to_Close'] = clean_closed_df.Date_to_Close.dt.days
type_means_df = clean_closed_df[['Case_type','Days_to_Close']].groupby('Case_type').mean().reset_index()
# Out:
# /Users/ayaspan/anaconda3/envs/mke_calls/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type_means_df.head()
# Out:
#                Case_type  Days_to_Close
# 0  Department Procedures      15.617284
# 1    Department Services      10.246575
# 2            Discourtesy       4.238095
# 3          No Allegation       1.125000
# 4                  Other       0.000000

# %%
create_bar_plot("Average Time to Close by Complaint Type:", type_means_df,'Case_type', count_type="Mean",
                agg_func_col ='Days_to_Close' , color = False, output=True, use_factor_map=Category20[type_means_df.shape[0]],
                need_counts=False, tooltip_captions = ['Case Type','Mean Time'], tooltip_cols = ['name','cts days'])
# Out:
#                Case_type  Days_to_Close
# 0  Department Procedures      15.617284
# 1    Department Services      10.246575
# 2            Discourtesy       4.238095
# 3          No Allegation       1.125000
# 4                  Other       0.000000
# 5     Unjustified Search      12.000000
# 6           Use of Force      48.600000
# Other
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8868">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="63d66438-f1d1-4254-8985-08e1fb4892a1"></div>

# %%
print(real_cats)
# Out:
# ['Department Procedures', 'Department Services', 'No Allegation', 'Discourtesy', 'Use of Force', 'Unjustified Search', 'Other']

# %%
import math


closed_cases_df['day_str'] = create_year_str(closed_cases_df, 'ReportedDay')



for cat in real_cats:
    sub_df = closed_cases_df[closed_cases_df['Case_type']==cat]
    #print(sub_df)
    #print(camel_to_snake(cat).replace('/',"_"))
    name = camel_to_snake(cat).replace('/',"_")
    #print(name)
    create_bar_plot(name+" Cases by Day of Week:", sub_df,'day_str', color = False, output=True, use_factor_map=Category20[len(real_cats)],
                need_counts=True, tooltip_captions = ['Case Type','By Day'], tooltip_cols = ['name','cts'])
# Out:
#   day_str  cts  day_int
# 0       0   20        0
# 3       1   15        1
# 2       2   17        2
# 4       3   11        3
# 1       4   18        4
# Department_procedures
# /Users/ayaspan/anaconda3/envs/mke_calls/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9266">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ec9723f1-f210-4452-a5fa-caba772bc17d"></div>
#   day_str  cts  day_int
# 2       0   16        0
# 4       1   10        1
# 1       2   17        2
# 0       3   18        3
# 3       4   12        4
# Department_services
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9672">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aa62b626-c6b6-4405-9080-670422414f00"></div>
#   day_str  cts  day_int
# 0       0   10        0
# 3       1    5        1
# 4       2    2        2
# 2       3    7        3
# 1       4    8        4
# No_allegation
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10086">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cadc1da2-6bb5-4ddf-879b-427ff88c0583"></div>
#   day_str  cts  day_int
# 3       0    4        0
# 1       1    5        1
# 4       2    3        2
# 2       3    4        3
# 0       4    5        4
# Discourtesy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10508">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d36d5d7f-46a9-44ca-8811-8a955c7d657c"></div>
#   day_str  cts  day_int
# 1       0    2        0
# 2       2    1        2
# 0       3    2        3
# Use_of_force
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10938">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="355725bb-4ea7-4a01-bcba-ee6179e4361d"></div>
#   day_str  cts  day_int
# 1       0    1        0
# 0       4    2        4
# Unjustified_search
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11376">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d68b6020-63ca-4c0b-9ca3-76e7b3733fcb"></div>
#   day_str  cts  day_int
# 0       0    1        0
# Other
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11822">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e491a120-0c25-4880-8bbb-8377115016a6"></div>
